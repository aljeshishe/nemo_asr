# %% [markdown]
# <a href="https://colab.research.google.com/github/aljeshishe/nemo_asr/blob/master/nemo_asr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/aljeshishe/nemo_asr
# Out:
# Cloning into 'nemo_asr'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 37 (delta 16), reused 31 (delta 10), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
cd nemo_asr
# Out:
# /content/nemo_asr

# %%
# !./install.sh
# Out:
# + export DEBIAN_FRONTEND=noninteractive
# + DEBIAN_FRONTEND=noninteractive
# + pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 703.8MB 26kB/s
# ...
#      |████████████████████████████████| 6.6MB 21.5MB/s
# ...
#   Found existing installation: torch 1.6.0+cu101
#     Uninstalling torch-1.6.0+cu101:
#       Successfully uninstalled torch-1.6.0+cu101
#   Found existing installation: torchvision 0.7.0+cu101
#     Uninstalling torchvision-0.7.0+cu101:
#       Successfully uninstalled torchvision-0.7.0+cu101
# ...
# + sudo apt install sox libsndfile1 ffmpeg wget -y
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-4ubuntu0.18.04.1).
# wget is already the newest version (1.19.4-1ubuntu2.2).
# ...

# %%
# !python3 main.py nemo_asr_cudnn_disabled_gpu1
# !python3 main.py nemo_asr_cudnn_disabled_gpu2
# !python3 main.py nemo_asr_cudnn_disabled_gpu3
# Out:
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################
#
# [NeMo W 2020-09-10 12:31:36 audio_preprocessing:56] Could not import torchaudio. Some features might not work.
# [NeMo W 2020-09-10 12:31:36 audio_preprocessing:61] Unable to import APEX. Mixed precision and distributed training will not work.
# Download the dataset. This will take a few moments...
# ******
# Dataset downloaded at: ./an4_sphere.tar.gz
# Converting .sph to .wav...
# Finished conversion.
# ******
# Building Manifest Files
# ******
# Training manifest created.
# Test manifest created.
# ******
# Config Information
# Instantiate Neural Modules
# ...
